# %%
import pandas as pd
url = '/content/50_Startups.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['Profit']), y= data['R&D Spend'])   #fit day du lieu
print('he so intercept la:',model.intercept_)
print('he so coeffient la:',model.coef_)
model.score(X=pd.DataFrame(data['Profit']), y= data['R&D Spend'])

y_pred = model.predict(X = pd.DataFrame(data['Profit']))
data.plot(kind = 'scatter',x = 'Profit',y = 'R&D Spend', figsize = (9,9), color = 'black')
plt.plot(data['Profit'],y_pred, color = 'blue')
# Out:
# he so intercept la: -50385.82883510302
# he so coeffient la: [1.10797715]
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Profit'],data['Profit']**2]).T
model.fit(X,y=data['R&D Spend'])
print('Intercept cua mo hinh:',model.intercept_)
print('coeffient cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:',model.score(X,y=data['R&D Spend']))
# Out:
# Intercept cua mo hinh: -37182.30912423563
# coeffient cua mo hinh: [8.39353178e-01 1.19427444e-06]
# Do chinh xac cua mo hinh: 0.9497292340096265

# %%
import numpy as np
range = np.arange(1,200000,1)
X_range= pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=X_range)
data.plot(kind = 'scatter',x ='Profit',y = 'R&D Spend',figsize=(9,9),color = 'black')
plt.plot(range, y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
range = np.arange(1,200000,1)
X_range= pd.DataFrame([range,range**2]).T
y_pred = model.predict(X=X_range)
data.plot(kind = 'scatter',x ='Profit',y = 'R&D Spend',figsize=(9,9),color = 'black')
plt.plot(range, y_pred,color='blue')
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Profit'],data['Profit']**2]).T
model.fit(X,y=data['R&D Spend'])
print('Intercept cua mo hinh:',model.intercept_)
print('coeffient cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:',model.score(X,y=data['R&D Spend']))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Intercept cua mo hinh: -37182.30912423563
# coeffient cua mo hinh: [8.39353178e-01 1.19427444e-06]
# Do chinh xac cua mo hinh: 0.9497292340096265

# %%
model = linear_model.LinearRegression()
X=pd.DataFrame([data['Profit'],data['Profit']**2,data['Profit']**3]).T
model.fit(X,y=data['R&D Spend'])
print('Intercept của mô hình:',model.intercept_)
print('Coeffient của mô hình:',model.coef_)
print('Độ chính xác của mô hình:',model.score(X=pd.DataFrame([data['Profit'],data['Profit']**2,data['Profit']**3]).T,y=data['R&D Spend']))

import numpy as np
range = np.arange(1,200000,1)
X_range=pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X=X_range)
data.plot(kind='scatter',x='Profit',y='R&D Spend',figsize=(9,9),color='black')
plt.plot(range,y_pred,color='blue')
# Out:
# Intercept của mô hình: 4485.290422215578
# Coeffient của mô hình: [-7.93166943e-01  1.84781036e-05 -5.31348360e-11]
# Độ chính xác của mô hình: 0.9654298048540076
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['Profit','Administration']],y=data['R&D Spend'])
print('Intercept la:',model.intercept_)
print('Coeffient la:',model.coef_)
print('Do chinh xac:',model.score(X=data.loc[:,['Profit','Administration']],y=data['R&D Spend']))
# Out:
# Intercept la: -58809.72271501801
# Coeffient la: [1.09685941 0.07968396]
# Do chinh xac: 0.948805615870854
