# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
digit=x_train[9]
from numpy import show_config
import matplotlib.pyplot as plt
plt.imshow(digit,cmap=plt.cm.binary)
plt.show()
print('Số:',y_train[9])

for i in range(15):
  plt.subplot(3,5,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation='none')
  plt.title('Số:{}'.format(y_train[i]))
  plt.xticks([])
  plt.yticks([])
# Out:
# Số: [3]
# <ipython-input-6-75958fb946fa>:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,5,i+1)

# %%
(x_train, y_train),(x_test,y_test)=cifar10.load_data()

# %%
from keras.utils import to_categorical
from keras.models import Sequential 
from keras.layers import Dense 
model = Sequential()
model.add(Dense(5000,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(3000,activation='relu'))
model.add(Dense(1000,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 5000)              15365000
#
#  dense_1 (Dense)             (None, 3000)              15003000
#
#  dense_2 (Dense)             (None, 1000)              3001000
#
#  dense_3 (Dense)             (None, 10)                10010
#
# ...
# Total params: 33,379,010
# Trainable params: 33,379,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
x=x_train
y=y_train

x_train = x_train.reshape(50000,32*32*3)
x_train = x_train.astype('float32')/255
x_test = x_test.reshape(10000,32*32*3)
x_test = x_test.astype('float32')/255
x_train.shape
# Out:
# (50000, 3072)

# %%
y_train = to_categorical(y_train,10)  
y_test = to_categorical(y_test,10)
y_train.shape
y_test.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Mất mát:',test_loss)
print('Độ chính xác:',test_acc)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 495s 1s/step - loss: 1.8849 - accuracy: 0.3188
# Epoch 2/10
# 391/391 [==============================] - 496s 1s/step - loss: 1.7662 - accuracy: 0.3627
# Epoch 3/10
# 391/391 [==============================] - 499s 1s/step - loss: 1.6893 - accuracy: 0.3940
# Epoch 4/10
# 391/391 [==============================] - 500s 1s/step - loss: 1.6261 - accuracy: 0.4136
# Epoch 5/10
# 391/391 [==============================] - 497s 1s/step - loss: 1.5738 - accuracy: 0.4367
# Epoch 6/10
# 391/391 [==============================] - 486s 1s/step - loss: 1.5361 - accuracy: 0.4500
# Epoch 7/10
# 391/391 [==============================] - 486s 1s/step - loss: 1.4969 - accuracy: 0.4631
# Epoch 8/10
# 391/391 [==============================] - 478s 1s/step - loss: 1.4643 - accuracy: 0.4792
# Epoch 9/10
# 391/391 [==============================] - 481s 1s/step - loss: 1.4302 - accuracy: 0.4871
# Epoch 10/10
# ...

# %%
digit = x[10]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
x_pred = x[500].reshape(1,32*32*3)
x_pred = x_pred.astype('float32')/255
y_pred = model.predict(x_pred)
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 198ms/step
# [[0.0881623  0.10431904 0.08833922 0.07072627 0.10185678 0.08436032
#   0.17408463 0.10739333 0.0870871  0.09367109]]

# %%
img=plt.imread('')
plt.imshow(img)
plt.show()

# %%
from keras.utils import load_img
img = load_img('/1434367715-ngua_1.jpg',target_size=(32,32))
plt.imshow(img)

# %%
from keras.utils import load_img
img = load_img('/content/drive/MyDrive/Colab Notebooks/1434367715-ngua_1.jpg',target_size=(32,32))
plt.imshow(img)

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive/MyDrive/Colab Notebooks/1434367715-ngua_1.jpg',target_size=(32,32))
from keras.utils import load_img,img_to_array
img=load_img('1434367715-ngua_1.jpg',target_size=(32,32)) 
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
np.argmax(model.predict(img),axis=-1)

# %%
from tensorflow.keras.utils import img_to_array
img = img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# array([7])
